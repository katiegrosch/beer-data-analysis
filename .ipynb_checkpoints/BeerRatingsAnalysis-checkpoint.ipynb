# %%
# loading the packages and modules

# %matplotlib inline

# general packages
import numpy as np
import pandas as pd
import sklearn

# for statistics
import scipy.stats as stats
import statsmodels.api as sm

# for visualizations
import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#loading and cleaning the data

df = pd.read_csv("beer.csv")

df = df.drop(['review/text', 'review/timeStruct','user/birthdayRaw','user/birthdayUnix'], axis=1)

df = df.rename(index=str, columns={'beer/ABV': 'ABV', 'user/gender':'gender', 'user/ageInSeconds':'ageInSeconds'})

df = df[np.abs(df.ABV-df.ABV.mean()) <= (3*df.ABV.std())]
df = df[df.ageInSeconds.notnull()]
df = df[df.gender.notnull()]

# %%
df.shape
# Out:
# (7704, 15)

# %%
df.describe()
# Out:
#               index          ABV   beer/beerId  beer/brewerId  \
# count   7704.000000  7704.000000   7704.000000    7704.000000
# mean   24857.609294     7.454991  21805.936397    3068.560618
# std    14371.382106     2.272365  18540.411751    5187.312029
# min        4.000000     0.500000    175.000000       1.000000
# 25%    12377.750000     5.500000   5441.000000     395.000000
# 50%    24981.500000     7.000000  18968.000000    1199.000000
# 75%    36951.750000     9.400000  34146.000000    1315.000000
# max    49974.000000    14.000000  77207.000000   26990.000000
#
#        review/appearance  review/aroma  review/overall  review/palate  \
# count        7704.000000   7704.000000     7704.000000    7704.000000
# mean            3.912318      3.897326        3.912059       3.866498
# std             0.590726      0.671394        0.698766       0.668260
# min             1.000000      1.000000        1.000000       1.000000
# ...
